# %%
import matplotlib
file = font_manager.findfont('Helvetica')
file
# Out:
# /home/ldavis/anaconda3/lib/python3.6/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# '/home/ldavis/anaconda3/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf'

# %%
import pyfuncs.plots as py
# Out:
# Registered colormaps.
# Default settings enabled.

# %%
py.fonts
# Out:
# ['Arial Black',
#  'Arial Narrow',
#  'Arial Narrow Bold',
#  'Arial Narrow Bold Italic',
#  'Arial Narrow Italic',
#  'Arial Rounded Bold',
#  'Arial Unicode',
#  'Cantarell-Bold',
#  'Cantarell-Regular',
#  'Courier',
#  'CourierBold',
#  'CourierBoldOblique',
#  'CourierOblique',
#  'DejaVuSans',
#  'DejaVuSans-Bold',
#  'DejaVuSans-BoldOblique',
#  'DejaVuSans-ExtraLight',
#  'DejaVuSans-Oblique',
#  'DejaVuSansCondensed',
#  'DejaVuSansCondensed-Bold',
#  'DejaVuSansCondensed-BoldOblique',
#  'DejaVuSansCondensed-Oblique',
#  'DejaVuSansDisplay',
#  'DejaVuSansMono',
#  'DejaVuSansMono-Bold',
#  'DejaVuSansMono-BoldOblique',
#  'DejaVuSansMono-Oblique',
#  'DejaVuSeri',
#  'DejaVuSerif',
#  'DejaVuSerif-Bold',
#  'DejaVuSerif-BoldItalic',
#  'DejaVuSerif-Italic',
#  'DejaVuSerifCondensed',
#  'DejaVuSerifCondensed-Bold',
#  'DejaVuSerifCondensed-BoldItalic',
#  'DejaVuSerifCondensed-Italic',
#  'DejaVuSerifDisplay',
#  'DroidNaskh-Bold',
#  'DroidNaskh-Regular',
#  'DroidSans',
# ...
